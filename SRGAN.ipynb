# %%
# !python3 "./drive/MyDrive/srgan_pytorch/datasets.py"
# !python3 "./drive/MyDrive/srgan_pytorch/model.py"
# !python3 "./drive/MyDrive/srgan_pytorch/utils.py"

# %%
# !python3 "./drive/MyDrive/srgan_pytorch/train.py" \
--train_file "/content/drive/MyDrive/srgan_pytorch/datasets/DIV2K_train_HR/DIV2K_train_HR" \
--val_file "/content/drive/MyDrive/srgan_pytorch/datasets/DIV2K_valid_HR/DIV2K_valid_HR" \
--outputs_dir "/content/drive/MyDrive/srgan_pytorch/checkpoint"

# %%
# !python3 "./drive/MyDrive/srgan_pytorch/run_srgan_model.py" \
--image_file "/content/drive/MyDrive/srgan_pytorch/testset" \
--weights_file "/content/drive/MyDrive/srgan_pytorch/checkpoint/SRGAN_x4/netG/epoch_4_80.pth"

# %%
# !python3 "./drive/MyDrive/srgan_pytorch/test.py" \
--test_image "/content/drive/MyDrive/srgan_pytorch/testset" \
--weights_file "/content/drive/MyDrive/srgan_pytorch/checkpoint/SRGAN_x4/netG/worked.pth"
